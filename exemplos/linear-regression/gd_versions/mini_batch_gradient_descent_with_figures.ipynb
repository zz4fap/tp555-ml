# %%
# Import all the necessary libraries.
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm
import random

# %%
# Reset the pseudo random number generator to the same value.
seed = 1234
np.random.seed(seed)
random.seed(seed)

# %% [markdown]
# ### Definição de funções úteis.

# %%
def gradientDescentMiniBatch(X, y_noisy, alpha, n_epochs, mb_size):
    '''Mini-batch gradient descent version'''
    
    # Retrieve number of samples.
    N = len(y_noisy)
    
    # Random initialization of parameters.
    a = np.array([-10.0, -10.0]).reshape(2, 1)

    # Create vector for parameter history.
    a_hist = np.zeros((2, n_epochs*(N//mb_size)+1))
    # Initialize history vector.
    a_hist[:, 0] = a.reshape(2,)

    # Create array for storing error values.
    Jgd = np.zeros(n_epochs*(N//mb_size)+1)

    Jgd[0] = (1.0/N)*sum(np.power(y_noisy - X.dot(a), 2))

    # Create array for storing gradient values.
    grad_hist = np.zeros((2, n_epochs*(N//mb_size)))

    # Mini-batch gradient-descent loop.
    inc = 0
    # Count the epochs.
    for e in range(n_epochs):

        # Shuffle the whole dataset before every epoch.
        shuffled_data_set_indexes = random.sample(range(0, N), N)

        # Count the iterations.
        for i in range(0, N//mb_size):

            # Randomly selecting one training example.
            start = i*mb_size
            end = mb_size*(i+1)
            batch_indexes = shuffled_data_set_indexes[start:end]
            xi = X[batch_indexes]
            yi = y_noisy[batch_indexes]

            # Calculate the approximation of the gradient.
            gradients = -(2.0/mb_size)*xi.T.dot(yi - xi.dot(a))
            
            # Update the weights.
            a = a - alpha*gradients

            # Calculate the MSE for the new weights.
            # The error is generally calculated after each epoch, but here, we want to see it after each iteration.
            Jgd[inc+1] = (1.0/N)*sum(np.power((y_noisy - X.dot(a)), 2))

            # Store history.
            grad_hist[:, inc] = gradients.reshape(2,)
            a_hist[:, inc+1] = a.reshape(2,)

            # Increment the iteration.
            inc = inc + 1
            
    return a, Jgd, a_hist, grad_hist, inc

# %% [markdown]
# ### Gerando a função observável.

# %%
# Define the number of examples.
N = 1000

# Attributes. 
x1 = np.random.randn(N, 1)
x2 = np.random.randn(N, 1)

# Target/true function.
y = x1 + x2

# Noise.
w = np.random.randn(N, 1)

# Observable function (noisy).
y_noisy = y + w

# %% [markdown]
# ### Plotando a função observável.

# %%
# Plot observable function.
fig = plt.figure(figsize=(7,7))
plt.subplot(projection='3d')
ax = fig.gca()
ax.scatter(x1,x2,y, label='Função verdadeira')
ax.scatter(x1,x2,y_noisy, label='Função observável')
ax.set_xlabel('$x_1$', fontsize=14)
ax.set_ylabel('$x_2$', fontsize=14)
ax.set_zlabel('$y$', fontsize=14)
plt.legend()
plt.show()

# %% [markdown]
# ### Encontrando a solução ótima com a equação normal.

# %%
# Concatenate both column vectors, x1 and x2.
X = np.c_[x1, x2]

# Closed-form solution.
a_opt = np.linalg.pinv(np.transpose(X).dot(X)).dot(np.transpose(X).dot(y_noisy))
yhat = X.dot(a_opt)
Joptimum = (1.0/N)*np.sum(np.power((y_noisy - yhat), 2))

# %% [markdown]
# ### Plotando a superfície de erro.

# %%
# Generate values for parameters.
M = 200
a1 = np.linspace(-12.0, 14.0, M)
a2 = np.linspace(-12.0, 14.0, M)

A1, A2 = np.meshgrid(a1, a2)

# Generate points for plotting the cost-function surface.
J = np.zeros((M,M))
for iter1 in range(0, M):
    for iter2 in range(0, M):
        yhat = A1[iter1, iter2]*x1 + A2[iter1, iter2]*x2
        J[iter1, iter2] = (1.0/N)*np.sum(np.square(y_noisy - yhat))

# %%
# Plot cost-function surface.
fig = plt.figure(figsize=(7,7))
plt.subplot(projection='3d')
ax = fig.gca()
surf = ax.plot_surface(A1, A2, J, cmap=cm.coolwarm, linewidth=0, antialiased=False)
ax.set_xlabel('$a_1$', fontsize=14)
ax.set_ylabel('$a_2$', fontsize=14)
ax.set_zlabel('$J_e$', fontsize=14)
plt.title('Cost-function\'s Surface')
#plt.savefig("error_surface_mb_gd.png", dpi=600)
#Show the plot.
plt.show()

# %% [markdown]
# ### Encontrando os pesos com o gradiente descendente em mini-lotes.

# %%
# Number of epochs.
n_epochs = 1
# Learning rate.
alpha = 0.2
# Mini-batch size.
mb_size = 10

# Call function that implements the mini-batch.
a, Jgd, a_hist, grad_hist, inc = gradientDescentMiniBatch(X, y_noisy, alpha, n_epochs, mb_size)

# %% [markdown]
# ### Plotando a superfície de contorno.

# %%
# Plot contour figure.        
fig = plt.figure(figsize=(5,5))
cp = plt.contour(A1, A2, J)
plt.clabel(cp, inline=1, fontsize=10)
plt.xlabel('$a_1$', fontsize=14)
plt.ylabel('$a_2$', fontsize=14)
plt.title('Cost-function\'s Contour')
plt.plot(a_opt[0], a_opt[1], c='r', marker='*')
plt.plot(a_hist[0, 0:inc+1], a_hist[1, 0:inc+1], 'kx')
plt.xticks(np.arange(-10, 12, step=2.0))
plt.yticks(np.arange(-10, 12, step=2.0))
#plt.savefig("error_contour_mb_gd.png", dpi=600)
plt.show()

# %% [markdown]
# ### Comparando os valores dos pesos.

# %%
# Print found values.
print('a0_opt: ' + str(a_opt[0, 0]))
print('a1_opt: ' + str(a_opt[1, 0]))

print('a0_sgd: ' + str(a[0, 0]))
print('a1_sgd: ' + str(a[1, 0]))
# Out:
# a0_opt: 1.0373518580863197
# a1_opt: 1.0549021717423768
# a0_sgd: 1.1763189434768013
# a1_sgd: 0.8585922595016274

# %% [markdown]
# ### Plotando o MSE em função das iterações.

# %%
fig = plt.figure(figsize=(5,5))

plt.plot(np.arange(0, inc+1), Jgd[0:inc+1])
plt.xlim((0, inc+1))
plt.yscale('log')
plt.xlabel('Iteration', fontsize=14)
plt.ylabel('$J_e$', fontsize=14)
plt.title('Error vs. Iteration number')
plt.grid()
#plt.savefig("error_vs_iteration_bgd.png", dpi=600)
plt.show()

# %% [markdown]
# ### Plotando a variação do gradiente ao longo das iterações.

# %%
fig = plt.figure(figsize=(5,5))

plt.plot(np.arange(0, inc), grad_hist[0,0:inc], 'x', label='$a_1$')
plt.plot(np.arange(0, inc), grad_hist[1,0:inc], label='$a_2$')
plt.plot(np.arange(0, inc), np.mean(grad_hist[1,:])*np.ones(inc), 'r', label='$mean(a_2)$')
plt.plot(np.arange(0, inc), np.mean(grad_hist[0,:])*np.ones(inc), 'k--', label='$mean(a_1)$')
plt.ylim([-20, 20])
plt.xlabel('Iteration', fontsize=14)
plt.ylabel('$\\nabla_e$', fontsize=14)
plt.title('Gradient vs. Iteration number')
plt.legend()
plt.grid()
plt.show()
