# %% [markdown]
# # Aproximação de funções para problemas de classificação.
#
# Neste exemplo, iremos combinar alguns neurônios para obter funções discriminantes com diferentes diferentes formatos.

# %%
# Import all necessary libraries and functions.
import numpy as np
from matplotlib import cm
import matplotlib.pyplot as plt
from sklearn.datasets import make_circles
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import confusion_matrix, accuracy_score
from sklearn.model_selection import GridSearchCV
from sklearn.datasets import make_moons
from sklearn.model_selection import KFold
import seaborn as sns

# %% [markdown]
# ## Definição de funções úteis.

# %%
def plotSamples(x1, x2, y, filename=''):
    '''Plot the samples.'''
    idx0 = np.argwhere(y == 0)
    idx1 = np.argwhere(y == 1)

    plt.plot(x1[idx0], x2[idx0], '.', label='Class 0')
    plt.plot(x1[idx1], x2[idx1], 'rx', label='Class 1')
    plt.xlabel('$x_1$', fontsize=14)
    plt.ylabel('$x_2$', fontsize=14)
    plt.legend()
    if(filename != ''): plt.savefig(filename, dpi=600)
    plt.grid()
    plt.show()

def plotDecisionBoundary(clf, x1, x2, filename=''):
    '''Plot the decision boundary.'''

    x_min, x_max = x1.min() - .5, x1.max() + .5
    y_min, y_max = x2.min() - .5, x2.max() + .5
    h = 250
    xx, yy = np.meshgrid(np.linspace(x_min, x_max, h), np.linspace(y_min, y_max, h))

    zz = np.zeros((xx.shape))
    for i in range(0, len(xx)):
        for j in range(0, len(yy)):
            aux = clf.predict_proba(np.c_[xx[i,j], yy[i,j]])
            zz[i,j] = aux[0,1]

    plt.figure(figsize=(12,5))
    ax = plt.subplot(1, 2, 1, projection='3d')
    ax.plot_surface(xx, yy, zz, cmap=cm.coolwarm, linewidth=0, antialiased=True)
    # Add a color bar which maps values to colors.
    ax.set_xlabel('$x_1$',fontsize=14)
    ax.set_ylabel('$x_2$',fontsize=14)
    ax.set_zlabel('$y$',fontsize=14)

    ax = plt.subplot(1, 2, 2)
    # Plot the decision boundary. For that, we will assign a color to each
    # point in the mesh [x_min, x_max]x[y_min, y_max].
    x_min, x_max = X[:, 0].min() - .5, X[:, 0].max() + .5
    y_min, y_max = X[:, 1].min() - .5, X[:, 1].max() + .5
    h = .02  # step size in the mesh
    # O meshgrid cria uma combinação de pontos (valores) entre os intervalos definidos para plotar as regiões de decisão.
    xx, yy = np.meshgrid(np.arange(x_min, x_max, h), np.arange(y_min, y_max, h))

    # This attribute matrix must also have the same shape
    # as the one created for the training.
    attribute_matrix = np.c_[xx.ravel(), yy.ravel()]

    Z = clf.predict(attribute_matrix)

    # Put the result into a color plot.
    Z = Z.reshape(xx.shape)
    ax.pcolormesh(xx, yy, Z, cmap=plt.cm.Greens, shading='auto')

    # Plot also the training points.
    idx0 = np.argwhere(y == 0)
    idx1 = np.argwhere(y == 1)
    ax.plot(X[idx0, 0], X[idx0, 1], '.', markersize=10, label='Class 0')
    ax.plot(X[idx1, 0], X[idx1, 1], 'r^', markersize=10, label='Class 1')
    ax.set_xlabel('$x_1$', fontsize=14)
    ax.set_ylabel('$x_2$', fontsize=14)

    ax.set_xlim(xx.min(), xx.max())
    ax.set_ylim(yy.min(), yy.max())

    ax.grid()
    if(filename != ''): plt.savefig(filename, dpi=600)
    plt.show()

# %% [markdown]
# ## Função lógica E (AND) com adição de ruído.

# %%
# Number of examples.
N = 10000

# Reset the PN sequence generator.
seed = 4
np.random.seed(seed)

# Attributes.
x1 = np.random.randint(0, 2, N)
x2 = np.random.randint(0, 2, N)

# Noise.
w1 = 0.1*np.random.randn(N,)
w2 = 0.1*np.random.randn(N,)

# AND labels.
y = x1 & x2

# Noisy attributes.
x1 = x1 + w1
x2 = x2 + w2

X = np.c_[x1, x2]

# %% [markdown]
# ### Plota as classes.

# %%
plotSamples(x1, x2, y)

# %% [markdown]
# ### Treinando a rede neural.
#
# + Usaremos um objeto da classe `MLPClassifier` da biblioteca scikit-learn para encontrar uma função discriminante que separe estas classes.
#
#
# + A classe `MLPClassifier` implementa uma rede neural multi-layer perceptron para tarefas de classificação, ou seja, ela terá um número de neurônios na camada de saída dependendo do problema. A função `softmax` é usada como ativação da camada de saída para problemas multiclasses (i.e., $Q>2$) ou a função `logística` para problemas binários (i.e., $Q=2$).
#
#
# + A classe `MLPClassifier` possui vários parâmetros que podem ser configurados, mas, dentre eles, os que usaremos serão
#     + `hidden_layer_sizes`: tupla que define a quantidade de camadas escondidas e nós em cada uma dessas camadas.
#     + `activation`: função de ativação de todos os nós das camadas ocultas.
#     + `solver`: o otimizador para atualização dos pesos dos nós da rede. Aqui usamos o `lbfgs` que é um algoritmo iterativo similar ao gradiente descendente, mas que além das derivadas de primeira ordem (vetor gradiente), usa informações das derivadas de segunda ordem da função de erro. Ele é indicado para bases de dados pequenas.
#
#
# + A documentação da classe pode ser encontrada em:
#     + https://scikit-learn.org/stable/modules/generated/sklearn.neural_network.MLPClassifier.html
#
#
# + Como a função AND é linearmente separável (ver figura acima), para classificar esta função, usaremos uma rede MLP com 0 camadas escondidas e apenas um neurônio na camada de saída.
#     + Ou seja, usaremos no total: 1 nó.
#
#
# + **OBS**.: Claro que é possível separar as classes com uma rede neural com mais nós e camadas, mas isso aumentaria a complexidade da rede, o que, consequentemente, pode ocasionar sobreajuste.

# %%
clf = MLPClassifier(hidden_layer_sizes=(), activation='logistic', solver='lbfgs', random_state=seed)

clf.fit(X, y)

y_pred = clf.predict(X)

acc = accuracy_score(y_pred, y)
print('Accuracy: ', acc)
# Out:
# Accuracy:  0.9997

# %%
# Acessando os pesos da camada de saída.
print('Output layer vector shape: ', clf.coefs_[0].shape)

# Número de camadas: entrada + saída.
print('n_layers: ', clf.n_layers_)

# Número de iterações até atingir o critério de parada.
print('n_iter: ', clf.n_iter_)
# Out:
# Output layer vector shape:  (2, 1)
# n_layers:  2
# n_iter:  16

# %%
# Plot the confusion matrix.
numberOfClasses = 2
mat = confusion_matrix(y, y_pred)
sns.heatmap(mat.T, square=True, annot=True, fmt='d', cbar=False, xticklabels=range(numberOfClasses), yticklabels=range(numberOfClasses), cmap="Blues")
plt.xlabel('true label')
plt.ylabel('predicted label')
plt.show()

# %% [markdown]
# ### Plotando as regiões de decisão.
#
# + A figura da esquerda mostra que um único nó aproxima uma **função de limiar suave**: saída da rede é um valor dentro do intervalo [0, 1].
#     + A figura mostra a função de limiar de decisão em 3D.
#
#
# + A figura da direita mostra a disposição das amostras das duas classes e a fronteira de decisão (i.e., localização da função discriminante).

# %%
plotDecisionBoundary(clf, x1, x2)

# %% [markdown]
# ## Função lógica XOR com adição de ruído.

# %%
# Number of examples.
N = 10000

# Reset the PN sequence generator.
seed = 4
np.random.seed(seed)

# Attributes.
x1 = np.random.randint(0,2,N)
x2 = np.random.randint(0,2,N)

# Noise.
w1 = 0.1*np.random.randn(N,)
w2 = 0.1*np.random.randn(N,)

# XOR labels.
y = x1 ^ x2

# Noisy attributes.
x1 = x1 + w1
x2 = x2 + w2

X = np.c_[x1,x2]

# %% [markdown]
# ### Plota as classes.

# %%
plotSamples(x1, x2, y)

# %% [markdown]
# ### Treinando a rede neural.
#
# + Como a função XOR não é linearmente separável, para classificá-la, usaremos uma rede MLP (instância da classe `MLPClassifier`) com 1 camada escondida com 2 nós e um neurônio na camada de saída.
#
#
# + A rede MLP terá um total de 3 nós.

# %%
clf1 = MLPClassifier(hidden_layer_sizes=(2,), activation='logistic', solver='lbfgs', random_state=seed)

clf1.fit(X, y)

y_pred = clf1.predict(X)

acc = accuracy_score(y_pred, y)
print('Accuracy: ', acc)
# Out:
# Accuracy:  0.9993

# %%
# Acessando os pesos da camada oculta.
print('Hidden layer matrix shape: ', clf1.coefs_[0].shape)

# Acessando os pesos da camada de saída.
print('Output layer vector shape: ', clf1.coefs_[1].shape)

# Número de camadas: entrada + oculta + saída.
print('n_layers: ', clf1.n_layers_)

# Número de iterações até atingir o critério de parada.
print('n_iter: ', clf1.n_iter_)
# Out:
# Hidden layer matrix shape:  (2, 2)
# Output layer vector shape:  (2, 1)
# n_layers:  3
# n_iter:  27

# %%
# Plot the confusion matrix.
numberOfClasses = 2
mat = confusion_matrix(y, y_pred)
sns.heatmap(mat.T, square=True, annot=True, fmt='d', cbar=False, xticklabels=range(numberOfClasses), yticklabels=range(numberOfClasses), cmap="Blues")
plt.xlabel('true label')
plt.ylabel('predicted label')
plt.show()

# %% [markdown]
# ### Plotando as regiões de decisão.
#
#
# + Combinando duas funções de limiar suave com direções opostas, podemos obter uma função com formato de onda.
#
#
# + A figura da direita mostra a disposição das amostras das duas classes e a fronteira de decisão (i.e., localização da função discriminante).

# %%
plotDecisionBoundary(clf1, x1, x2)

# %% [markdown]
# ## Círculos concêntricos com adição de ruído.

# %%
# Reset the PN sequence generator.
seed = 0
np.random.seed(seed)

# Number of samples.
N = 1000

# Create concentric circles with the addition of noise.
    # noise: desvio padrão do ruído Gaussiano adicionado às amostras.
    # factor: fator de escala entre os dois círculos.
X, y = make_circles(n_samples=N, noise=0.1, factor=0.2, random_state=42)

# %% [markdown]
# ### Plota as classes.

# %%
plotSamples(X[:,0], X[:,1], y)

# %% [markdown]
# ### Treinando a rede neural.
#
# + Para classificar os círculos concêntricos, usaremos uma rede MLP com 1 camada escondida com 4 nós e apenas um neurônio na camada de saída.
#
#
# + A rede MLP terá um total de 5 nós.

# %%
clf2 = MLPClassifier(hidden_layer_sizes=(4,), activation='logistic', solver='lbfgs', random_state=seed)

clf2.fit(X, y)

y_pred = clf2.predict(X)

acc = accuracy_score(y_pred, y)
print('Accuracy: ', acc)
# Out:
# Accuracy:  0.999

# %%
# Acessando os pesos da camada oculta.
print('Hidden layer vector shape: ', clf2.coefs_[0].shape)

# Acessando os pesos da camada de saída.
print('Output layer vector shape: ', clf2.coefs_[1].shape)

# Número de camadas: entrada + oculta + saída.
print('n_layers: ', clf2.n_layers_)

# Número de iterações até atingir o critério de parada.
print('n_iter: ', clf2.n_iter_)
# Out:
# Hidden layer vector shape:  (2, 4)
# Output layer vector shape:  (4, 1)
# n_layers:  3
# n_iter:  47

# %%
# Plot the confusion matrix.
numberOfClasses = 2
mat = confusion_matrix(y, y_pred)
sns.heatmap(mat.T, square=True, annot=True, fmt='d', cbar=False, xticklabels=range(numberOfClasses), yticklabels=range(numberOfClasses), cmap="Blues")
plt.xlabel('true label')
plt.ylabel('predicted label')
plt.show()

# %% [markdown]
# ### Plotando as regiões de decisão.
#
# + Combinando duas ondas perpendiculares, nós obtemos uma função com formato similar a de um triângulo (algumas vezes, dependendo da semente, o formato pode ser o de um quadrado).
#
#
# + A figura da direita mostra a disposição das amostras das duas classes e a fronteira de decisão (i.e., localização da função discriminante).

# %%
plotDecisionBoundary(clf2, X[:,0], X[:,1])

# %% [markdown]
# ## Duas luas

# %%
# Number of samples.
N = 1000

# Generate the dataset.
X, y = make_moons(n_samples=N, noise=0.05, random_state=seed)

# %% [markdown]
# ### Plota as classes.

# %%
plotSamples(X[:,0], X[:,1], y)

# %% [markdown]
# ## Qual deve ser a arquitetura para separar as duas classes?

# %% [markdown]
# ### Encontrando os melhores hiperparâmetros.

# %%
# Dictionary with the hyperparameters to be checked.
parameters = {
    'hidden_layer_sizes' : [(4,2), (3,4), (3,6), (4,8)],
    'activation' : ['logistic', 'relu'],
    'solver' : ['lbfgs', 'sgd', 'adam']
}

# Instantiate MLPRegressor.
reg = MLPClassifier(max_iter=5000, random_state=seed)

# Instantiate KFold.
kf = KFold(n_splits=10, shuffle=True, random_state=seed)

# Instantiate GridSearchCV.
gs = GridSearchCV(reg, parameters, scoring='accuracy', verbose=4, cv=kf)

# Train the MLPRegressor with grid search.
gs.fit(X, y)
# Out:
# Fitting 10 folds for each of 24 candidates, totalling 240 fits
# [CV 1/10] END activation=logistic, hidden_layer_sizes=(4, 2), solver=lbfgs;, score=1.000 total time=   0.1s
# [CV 2/10] END activation=logistic, hidden_layer_sizes=(4, 2), solver=lbfgs;, score=1.000 total time=   0.0s
# [CV 3/10] END activation=logistic, hidden_layer_sizes=(4, 2), solver=lbfgs;, score=1.000 total time=   0.0s
# [CV 4/10] END activation=logistic, hidden_layer_sizes=(4, 2), solver=lbfgs;, score=1.000 total time=   0.0s
# [CV 5/10] END activation=logistic, hidden_layer_sizes=(4, 2), solver=lbfgs;, score=1.000 total time=   0.1s
# [CV 6/10] END activation=logistic, hidden_layer_sizes=(4, 2), solver=lbfgs;, score=1.000 total time=   0.0s
# [CV 7/10] END activation=logistic, hidden_layer_sizes=(4, 2), solver=lbfgs;, score=1.000 total time=   0.0s
# [CV 8/10] END activation=logistic, hidden_layer_sizes=(4, 2), solver=lbfgs;, score=1.000 total time=   0.0s
# [CV 9/10] END activation=logistic, hidden_layer_sizes=(4, 2), solver=lbfgs;, score=1.000 total time=   0.0s
# [CV 10/10] END activation=logistic, hidden_layer_sizes=(4, 2), solver=lbfgs;, score=1.000 total time=   0.0s
# [CV 1/10] END activation=logistic, hidden_layer_sizes=(4, 2), solver=sgd;, score=0.450 total time=   0.1s
# [CV 2/10] END activation=logistic, hidden_layer_sizes=(4, 2), solver=sgd;, score=0.470 total time=   0.1s
# [CV 3/10] END activation=logistic, hidden_layer_sizes=(4, 2), solver=sgd;, score=0.530 total time=   0.1s
# [CV 4/10] END activation=logistic, hidden_layer_sizes=(4, 2), solver=sgd;, score=0.620 total time=   0.1s
# [CV 5/10] END activation=logistic, hidden_layer_sizes=(4, 2), solver=sgd;, score=0.470 total time=   0.1s
# [CV 6/10] END activation=logistic, hidden_layer_sizes=(4, 2), solver=sgd;, score=0.540 total time=   0.1s
# [CV 7/10] END activation=logistic, hidden_layer_sizes=(4, 2), solver=sgd;, score=0.420 total time=   0.1s
# [CV 8/10] END activation=logistic, hidden_layer_sizes=(4, 2), solver=sgd;, score=0.520 total time=   0.1s
# [CV 9/10] END activation=logistic, hidden_layer_sizes=(4, 2), solver=sgd;, score=0.450 total time=   0.1s
# [CV 10/10] END activation=logistic, hidden_layer_sizes=(4, 2), solver=sgd;, score=0.530 total time=   0.1s
# [CV 1/10] END activation=logistic, hidden_layer_sizes=(4, 2), solver=adam;, score=0.910 total time=   1.2s
# [CV 2/10] END activation=logistic, hidden_layer_sizes=(4, 2), solver=adam;, score=0.860 total time=   1.2s
# [CV 3/10] END activation=logistic, hidden_layer_sizes=(4, 2), solver=adam;, score=0.880 total time=   1.3s
# [CV 4/10] END activation=logistic, hidden_layer_sizes=(4, 2), solver=adam;, score=0.880 total time=   1.2s
# [CV 5/10] END activation=logistic, hidden_layer_sizes=(4, 2), solver=adam;, score=0.880 total time=   1.2s
# [CV 6/10] END activation=logistic, hidden_layer_sizes=(4, 2), solver=adam;, score=0.930 total time=   1.9s
# [CV 7/10] END activation=logistic, hidden_layer_sizes=(4, 2), solver=adam;, score=0.930 total time=   1.9s
# [CV 8/10] END activation=logistic, hidden_layer_sizes=(4, 2), solver=adam;, score=0.820 total time=   1.7s
# [CV 9/10] END activation=logistic, hidden_layer_sizes=(4, 2), solver=adam;, score=0.850 total time=   1.2s
# [CV 10/10] END activation=logistic, hidden_layer_sizes=(4, 2), solver=adam;, score=0.860 total time=   1.3s
# [CV 1/10] END activation=logistic, hidden_layer_sizes=(3, 4), solver=lbfgs;, score=1.000 total time=   0.1s
# [CV 2/10] END activation=logistic, hidden_layer_sizes=(3, 4), solver=lbfgs;, score=1.000 total time=   0.1s
# [CV 3/10] END activation=logistic, hidden_layer_sizes=(3, 4), solver=lbfgs;, score=1.000 total time=   0.1s
# [CV 4/10] END activation=logistic, hidden_layer_sizes=(3, 4), solver=lbfgs;, score=1.000 total time=   0.1s
# [CV 5/10] END activation=logistic, hidden_layer_sizes=(3, 4), solver=lbfgs;, score=1.000 total time=   0.1s
# [CV 6/10] END activation=logistic, hidden_layer_sizes=(3, 4), solver=lbfgs;, score=1.000 total time=   0.1s
# [CV 7/10] END activation=logistic, hidden_layer_sizes=(3, 4), solver=lbfgs;, score=1.000 total time=   0.1s
# [CV 8/10] END activation=logistic, hidden_layer_sizes=(3, 4), solver=lbfgs;, score=1.000 total time=   0.1s
# [CV 9/10] END activation=logistic, hidden_layer_sizes=(3, 4), solver=lbfgs;, score=1.000 total time=   0.1s
# [CV 10/10] END activation=logistic, hidden_layer_sizes=(3, 4), solver=lbfgs;, score=1.000 total time=   0.1s
# [CV 1/10] END activation=logistic, hidden_layer_sizes=(3, 4), solver=sgd;, score=0.550 total time=   0.0s
# [CV 2/10] END activation=logistic, hidden_layer_sizes=(3, 4), solver=sgd;, score=0.530 total time=   0.0s
# [CV 3/10] END activation=logistic, hidden_layer_sizes=(3, 4), solver=sgd;, score=0.470 total time=   0.0s
# [CV 4/10] END activation=logistic, hidden_layer_sizes=(3, 4), solver=sgd;, score=0.380 total time=   0.0s
# [CV 5/10] END activation=logistic, hidden_layer_sizes=(3, 4), solver=sgd;, score=0.530 total time=   0.0s
# [CV 6/10] END activation=logistic, hidden_layer_sizes=(3, 4), solver=sgd;, score=0.460 total time=   0.0s
# [CV 7/10] END activation=logistic, hidden_layer_sizes=(3, 4), solver=sgd;, score=0.580 total time=   0.0s
# [CV 8/10] END activation=logistic, hidden_layer_sizes=(3, 4), solver=sgd;, score=0.480 total time=   0.0s
# [CV 9/10] END activation=logistic, hidden_layer_sizes=(3, 4), solver=sgd;, score=0.550 total time=   0.0s
# [CV 10/10] END activation=logistic, hidden_layer_sizes=(3, 4), solver=sgd;, score=0.470 total time=   0.0s
# [CV 1/10] END activation=logistic, hidden_layer_sizes=(3, 4), solver=adam;, score=0.920 total time=   0.9s
# [CV 2/10] END activation=logistic, hidden_layer_sizes=(3, 4), solver=adam;, score=0.870 total time=   0.9s
# [CV 3/10] END activation=logistic, hidden_layer_sizes=(3, 4), solver=adam;, score=0.870 total time=   0.9s
# [CV 4/10] END activation=logistic, hidden_layer_sizes=(3, 4), solver=adam;, score=0.870 total time=   0.9s
# [CV 5/10] END activation=logistic, hidden_layer_sizes=(3, 4), solver=adam;, score=0.870 total time=   1.1s
# [CV 6/10] END activation=logistic, hidden_layer_sizes=(3, 4), solver=adam;, score=0.930 total time=   1.5s
# [CV 7/10] END activation=logistic, hidden_layer_sizes=(3, 4), solver=adam;, score=0.930 total time=   1.5s
# [CV 8/10] END activation=logistic, hidden_layer_sizes=(3, 4), solver=adam;, score=0.810 total time=   1.6s
# [CV 9/10] END activation=logistic, hidden_layer_sizes=(3, 4), solver=adam;, score=0.890 total time=   1.1s
# [CV 10/10] END activation=logistic, hidden_layer_sizes=(3, 4), solver=adam;, score=0.870 total time=   1.1s
# [CV 1/10] END activation=logistic, hidden_layer_sizes=(3, 6), solver=lbfgs;, score=0.910 total time=   0.1s
# [CV 2/10] END activation=logistic, hidden_layer_sizes=(3, 6), solver=lbfgs;, score=1.000 total time=   0.0s
# [CV 3/10] END activation=logistic, hidden_layer_sizes=(3, 6), solver=lbfgs;, score=1.000 total time=   0.1s
# [CV 4/10] END activation=logistic, hidden_layer_sizes=(3, 6), solver=lbfgs;, score=0.860 total time=   0.1s
# [CV 5/10] END activation=logistic, hidden_layer_sizes=(3, 6), solver=lbfgs;, score=0.900 total time=   0.1s
# [CV 6/10] END activation=logistic, hidden_layer_sizes=(3, 6), solver=lbfgs;, score=0.920 total time=   0.1s
# [CV 7/10] END activation=logistic, hidden_layer_sizes=(3, 6), solver=lbfgs;, score=1.000 total time=   0.1s
# [CV 8/10] END activation=logistic, hidden_layer_sizes=(3, 6), solver=lbfgs;, score=1.000 total time=   0.2s
# [CV 9/10] END activation=logistic, hidden_layer_sizes=(3, 6), solver=lbfgs;, score=0.990 total time=   0.0s
# [CV 10/10] END activation=logistic, hidden_layer_sizes=(3, 6), solver=lbfgs;, score=0.930 total time=   0.1s
# [CV 1/10] END activation=logistic, hidden_layer_sizes=(3, 6), solver=sgd;, score=0.550 total time=   0.1s
# [CV 2/10] END activation=logistic, hidden_layer_sizes=(3, 6), solver=sgd;, score=0.530 total time=   0.1s
# [CV 3/10] END activation=logistic, hidden_layer_sizes=(3, 6), solver=sgd;, score=0.470 total time=   0.1s
# [CV 4/10] END activation=logistic, hidden_layer_sizes=(3, 6), solver=sgd;, score=0.380 total time=   0.1s
# [CV 5/10] END activation=logistic, hidden_layer_sizes=(3, 6), solver=sgd;, score=0.530 total time=   0.2s
# [CV 6/10] END activation=logistic, hidden_layer_sizes=(3, 6), solver=sgd;, score=0.460 total time=   0.1s
# [CV 7/10] END activation=logistic, hidden_layer_sizes=(3, 6), solver=sgd;, score=0.580 total time=   0.1s
# [CV 8/10] END activation=logistic, hidden_layer_sizes=(3, 6), solver=sgd;, score=0.480 total time=   0.1s
# [CV 9/10] END activation=logistic, hidden_layer_sizes=(3, 6), solver=sgd;, score=0.550 total time=   0.1s
# [CV 10/10] END activation=logistic, hidden_layer_sizes=(3, 6), solver=sgd;, score=0.470 total time=   0.1s
# [CV 1/10] END activation=logistic, hidden_layer_sizes=(3, 6), solver=adam;, score=0.920 total time=   1.2s
# [CV 2/10] END activation=logistic, hidden_layer_sizes=(3, 6), solver=adam;, score=0.870 total time=   1.4s
# [CV 3/10] END activation=logistic, hidden_layer_sizes=(3, 6), solver=adam;, score=0.870 total time=   1.3s
# [CV 4/10] END activation=logistic, hidden_layer_sizes=(3, 6), solver=adam;, score=0.870 total time=   1.3s
# [CV 5/10] END activation=logistic, hidden_layer_sizes=(3, 6), solver=adam;, score=0.870 total time=   1.4s
# [CV 6/10] END activation=logistic, hidden_layer_sizes=(3, 6), solver=adam;, score=0.930 total time=   1.2s
# [CV 7/10] END activation=logistic, hidden_layer_sizes=(3, 6), solver=adam;, score=0.930 total time=   0.8s
# [CV 8/10] END activation=logistic, hidden_layer_sizes=(3, 6), solver=adam;, score=0.810 total time=   0.9s
# [CV 9/10] END activation=logistic, hidden_layer_sizes=(3, 6), solver=adam;, score=0.880 total time=   0.9s
# [CV 10/10] END activation=logistic, hidden_layer_sizes=(3, 6), solver=adam;, score=0.860 total time=   0.8s
# [CV 1/10] END activation=logistic, hidden_layer_sizes=(4, 8), solver=lbfgs;, score=1.000 total time=   0.1s
# [CV 2/10] END activation=logistic, hidden_layer_sizes=(4, 8), solver=lbfgs;, score=1.000 total time=   0.1s
# [CV 3/10] END activation=logistic, hidden_layer_sizes=(4, 8), solver=lbfgs;, score=1.000 total time=   0.1s
# [CV 4/10] END activation=logistic, hidden_layer_sizes=(4, 8), solver=lbfgs;, score=1.000 total time=   0.1s
# [CV 5/10] END activation=logistic, hidden_layer_sizes=(4, 8), solver=lbfgs;, score=1.000 total time=   0.1s
# [CV 6/10] END activation=logistic, hidden_layer_sizes=(4, 8), solver=lbfgs;, score=1.000 total time=   0.1s
# [CV 7/10] END activation=logistic, hidden_layer_sizes=(4, 8), solver=lbfgs;, score=1.000 total time=   0.1s
# [CV 8/10] END activation=logistic, hidden_layer_sizes=(4, 8), solver=lbfgs;, score=1.000 total time=   0.0s
# [CV 9/10] END activation=logistic, hidden_layer_sizes=(4, 8), solver=lbfgs;, score=1.000 total time=   0.1s
# [CV 10/10] END activation=logistic, hidden_layer_sizes=(4, 8), solver=lbfgs;, score=1.000 total time=   0.1s
# [CV 1/10] END activation=logistic, hidden_layer_sizes=(4, 8), solver=sgd;, score=0.450 total time=   0.1s
# [CV 2/10] END activation=logistic, hidden_layer_sizes=(4, 8), solver=sgd;, score=0.470 total time=   0.1s
# [CV 3/10] END activation=logistic, hidden_layer_sizes=(4, 8), solver=sgd;, score=0.530 total time=   0.1s
# [CV 4/10] END activation=logistic, hidden_layer_sizes=(4, 8), solver=sgd;, score=0.620 total time=   0.1s
# [CV 5/10] END activation=logistic, hidden_layer_sizes=(4, 8), solver=sgd;, score=0.470 total time=   0.1s
# [CV 6/10] END activation=logistic, hidden_layer_sizes=(4, 8), solver=sgd;, score=0.540 total time=   0.1s
# [CV 7/10] END activation=logistic, hidden_layer_sizes=(4, 8), solver=sgd;, score=0.420 total time=   0.1s
# [CV 8/10] END activation=logistic, hidden_layer_sizes=(4, 8), solver=sgd;, score=0.520 total time=   0.1s
# [CV 9/10] END activation=logistic, hidden_layer_sizes=(4, 8), solver=sgd;, score=0.450 total time=   0.1s
# [CV 10/10] END activation=logistic, hidden_layer_sizes=(4, 8), solver=sgd;, score=0.530 total time=   0.1s
# [CV 1/10] END activation=logistic, hidden_layer_sizes=(4, 8), solver=adam;, score=0.920 total time=   0.9s
# [CV 2/10] END activation=logistic, hidden_layer_sizes=(4, 8), solver=adam;, score=0.870 total time=   0.9s
# [CV 3/10] END activation=logistic, hidden_layer_sizes=(4, 8), solver=adam;, score=0.870 total time=   0.9s
# [CV 4/10] END activation=logistic, hidden_layer_sizes=(4, 8), solver=adam;, score=0.870 total time=   0.9s
# [CV 5/10] END activation=logistic, hidden_layer_sizes=(4, 8), solver=adam;, score=0.870 total time=   1.1s
# [CV 6/10] END activation=logistic, hidden_layer_sizes=(4, 8), solver=adam;, score=0.930 total time=   1.4s
# [CV 7/10] END activation=logistic, hidden_layer_sizes=(4, 8), solver=adam;, score=0.930 total time=   1.5s
# [CV 8/10] END activation=logistic, hidden_layer_sizes=(4, 8), solver=adam;, score=0.810 total time=   0.9s
# [CV 9/10] END activation=logistic, hidden_layer_sizes=(4, 8), solver=adam;, score=0.890 total time=   0.9s
# [CV 10/10] END activation=logistic, hidden_layer_sizes=(4, 8), solver=adam;, score=0.870 total time=   0.9s
# [CV 1/10] END activation=relu, hidden_layer_sizes=(4, 2), solver=lbfgs;, score=0.880 total time=   0.1s
# [CV 2/10] END activation=relu, hidden_layer_sizes=(4, 2), solver=lbfgs;, score=0.900 total time=   0.1s
# [CV 3/10] END activation=relu, hidden_layer_sizes=(4, 2), solver=lbfgs;, score=0.870 total time=   0.1s
# [CV 4/10] END activation=relu, hidden_layer_sizes=(4, 2), solver=lbfgs;, score=0.910 total time=   0.1s
# [CV 5/10] END activation=relu, hidden_layer_sizes=(4, 2), solver=lbfgs;, score=0.890 total time=   0.1s
# [CV 6/10] END activation=relu, hidden_layer_sizes=(4, 2), solver=lbfgs;, score=0.920 total time=   0.1s
# [CV 7/10] END activation=relu, hidden_layer_sizes=(4, 2), solver=lbfgs;, score=0.950 total time=   0.1s
# [CV 8/10] END activation=relu, hidden_layer_sizes=(4, 2), solver=lbfgs;, score=0.850 total time=   0.1s
# [CV 9/10] END activation=relu, hidden_layer_sizes=(4, 2), solver=lbfgs;, score=0.870 total time=   0.1s
# [CV 10/10] END activation=relu, hidden_layer_sizes=(4, 2), solver=lbfgs;, score=0.850 total time=   0.1s
# [CV 1/10] END activation=relu, hidden_layer_sizes=(4, 2), solver=sgd;, score=0.880 total time=   0.6s
# [CV 2/10] END activation=relu, hidden_layer_sizes=(4, 2), solver=sgd;, score=0.900 total time=   0.6s
# [CV 3/10] END activation=relu, hidden_layer_sizes=(4, 2), solver=sgd;, score=0.880 total time=   0.6s
# [CV 4/10] END activation=relu, hidden_layer_sizes=(4, 2), solver=sgd;, score=0.860 total time=   0.6s
# [CV 5/10] END activation=relu, hidden_layer_sizes=(4, 2), solver=sgd;, score=0.880 total time=   0.6s
# [CV 6/10] END activation=relu, hidden_layer_sizes=(4, 2), solver=sgd;, score=0.930 total time=   0.6s
# [CV 7/10] END activation=relu, hidden_layer_sizes=(4, 2), solver=sgd;, score=0.930 total time=   0.6s
# [CV 8/10] END activation=relu, hidden_layer_sizes=(4, 2), solver=sgd;, score=0.810 total time=   0.5s
# [CV 9/10] END activation=relu, hidden_layer_sizes=(4, 2), solver=sgd;, score=0.880 total time=   0.6s
# [CV 10/10] END activation=relu, hidden_layer_sizes=(4, 2), solver=sgd;, score=0.880 total time=   0.6s
# [CV 1/10] END activation=relu, hidden_layer_sizes=(4, 2), solver=adam;, score=0.900 total time=   1.2s
# [CV 2/10] END activation=relu, hidden_layer_sizes=(4, 2), solver=adam;, score=0.890 total time=   1.5s
# [CV 3/10] END activation=relu, hidden_layer_sizes=(4, 2), solver=adam;, score=0.880 total time=   1.3s
# [CV 4/10] END activation=relu, hidden_layer_sizes=(4, 2), solver=adam;, score=0.900 total time=   0.9s
# [CV 5/10] END activation=relu, hidden_layer_sizes=(4, 2), solver=adam;, score=0.890 total time=   1.0s
# [CV 6/10] END activation=relu, hidden_layer_sizes=(4, 2), solver=adam;, score=0.920 total time=   0.9s
# [CV 7/10] END activation=relu, hidden_layer_sizes=(4, 2), solver=adam;, score=0.960 total time=   0.9s
# [CV 8/10] END activation=relu, hidden_layer_sizes=(4, 2), solver=adam;, score=0.840 total time=   1.0s
# [CV 9/10] END activation=relu, hidden_layer_sizes=(4, 2), solver=adam;, score=0.870 total time=   1.4s
# [CV 10/10] END activation=relu, hidden_layer_sizes=(4, 2), solver=adam;, score=0.850 total time=   0.8s
# [CV 1/10] END activation=relu, hidden_layer_sizes=(3, 4), solver=lbfgs;, score=0.880 total time=   0.1s
# [CV 2/10] END activation=relu, hidden_layer_sizes=(3, 4), solver=lbfgs;, score=0.910 total time=   0.1s
# [CV 3/10] END activation=relu, hidden_layer_sizes=(3, 4), solver=lbfgs;, score=0.860 total time=   0.2s
# [CV 4/10] END activation=relu, hidden_layer_sizes=(3, 4), solver=lbfgs;, score=0.860 total time=   0.1s
# [CV 5/10] END activation=relu, hidden_layer_sizes=(3, 4), solver=lbfgs;, score=0.870 total time=   0.1s
# [CV 6/10] END activation=relu, hidden_layer_sizes=(3, 4), solver=lbfgs;, score=0.920 total time=   0.1s
# [CV 7/10] END activation=relu, hidden_layer_sizes=(3, 4), solver=lbfgs;, score=0.940 total time=   0.1s
# [CV 8/10] END activation=relu, hidden_layer_sizes=(3, 4), solver=lbfgs;, score=0.850 total time=   0.1s
# [CV 9/10] END activation=relu, hidden_layer_sizes=(3, 4), solver=lbfgs;, score=0.900 total time=   0.1s
# [CV 10/10] END activation=relu, hidden_layer_sizes=(3, 4), solver=lbfgs;, score=0.880 total time=   0.1s
# [CV 1/10] END activation=relu, hidden_layer_sizes=(3, 4), solver=sgd;, score=0.880 total time=   0.6s
# [CV 2/10] END activation=relu, hidden_layer_sizes=(3, 4), solver=sgd;, score=0.890 total time=   0.6s
# [CV 3/10] END activation=relu, hidden_layer_sizes=(3, 4), solver=sgd;, score=0.890 total time=   0.6s
# [CV 4/10] END activation=relu, hidden_layer_sizes=(3, 4), solver=sgd;, score=0.870 total time=   0.9s
# [CV 5/10] END activation=relu, hidden_layer_sizes=(3, 4), solver=sgd;, score=0.870 total time=   0.8s
# [CV 6/10] END activation=relu, hidden_layer_sizes=(3, 4), solver=sgd;, score=0.920 total time=   1.0s
# [CV 7/10] END activation=relu, hidden_layer_sizes=(3, 4), solver=sgd;, score=0.940 total time=   0.8s
# [CV 8/10] END activation=relu, hidden_layer_sizes=(3, 4), solver=sgd;, score=0.810 total time=   0.6s
# [CV 9/10] END activation=relu, hidden_layer_sizes=(3, 4), solver=sgd;, score=0.880 total time=   0.6s
# [CV 10/10] END activation=relu, hidden_layer_sizes=(3, 4), solver=sgd;, score=0.870 total time=   0.6s
# [CV 1/10] END activation=relu, hidden_layer_sizes=(3, 4), solver=adam;, score=0.920 total time=   0.5s
# [CV 2/10] END activation=relu, hidden_layer_sizes=(3, 4), solver=adam;, score=0.880 total time=   0.5s
# [CV 3/10] END activation=relu, hidden_layer_sizes=(3, 4), solver=adam;, score=0.870 total time=   0.4s
# [CV 4/10] END activation=relu, hidden_layer_sizes=(3, 4), solver=adam;, score=0.870 total time=   0.4s
# [CV 5/10] END activation=relu, hidden_layer_sizes=(3, 4), solver=adam;, score=0.870 total time=   0.4s
# [CV 6/10] END activation=relu, hidden_layer_sizes=(3, 4), solver=adam;, score=0.930 total time=   0.4s
# [CV 7/10] END activation=relu, hidden_layer_sizes=(3, 4), solver=adam;, score=0.930 total time=   0.4s
# [CV 8/10] END activation=relu, hidden_layer_sizes=(3, 4), solver=adam;, score=0.810 total time=   0.4s
# [CV 9/10] END activation=relu, hidden_layer_sizes=(3, 4), solver=adam;, score=0.890 total time=   0.5s
# [CV 10/10] END activation=relu, hidden_layer_sizes=(3, 4), solver=adam;, score=0.870 total time=   0.4s
# [CV 1/10] END activation=relu, hidden_layer_sizes=(3, 6), solver=lbfgs;, score=0.990 total time=   0.1s
# [CV 2/10] END activation=relu, hidden_layer_sizes=(3, 6), solver=lbfgs;, score=0.880 total time=   0.1s
# [CV 3/10] END activation=relu, hidden_layer_sizes=(3, 6), solver=lbfgs;, score=0.880 total time=   0.1s
# [CV 4/10] END activation=relu, hidden_layer_sizes=(3, 6), solver=lbfgs;, score=0.860 total time=   0.1s
# [CV 5/10] END activation=relu, hidden_layer_sizes=(3, 6), solver=lbfgs;, score=0.900 total time=   0.1s
# [CV 6/10] END activation=relu, hidden_layer_sizes=(3, 6), solver=lbfgs;, score=0.920 total time=   0.1s
# [CV 7/10] END activation=relu, hidden_layer_sizes=(3, 6), solver=lbfgs;, score=0.940 total time=   0.1s
# [CV 8/10] END activation=relu, hidden_layer_sizes=(3, 6), solver=lbfgs;, score=0.850 total time=   0.1s
# [CV 9/10] END activation=relu, hidden_layer_sizes=(3, 6), solver=lbfgs;, score=0.930 total time=   0.1s
# [CV 10/10] END activation=relu, hidden_layer_sizes=(3, 6), solver=lbfgs;, score=0.850 total time=   0.1s
# [CV 1/10] END activation=relu, hidden_layer_sizes=(3, 6), solver=sgd;, score=0.880 total time=   0.6s
# [CV 2/10] END activation=relu, hidden_layer_sizes=(3, 6), solver=sgd;, score=0.890 total time=   0.6s
# [CV 3/10] END activation=relu, hidden_layer_sizes=(3, 6), solver=sgd;, score=0.890 total time=   0.6s
# [CV 4/10] END activation=relu, hidden_layer_sizes=(3, 6), solver=sgd;, score=0.860 total time=   0.6s
# [CV 5/10] END activation=relu, hidden_layer_sizes=(3, 6), solver=sgd;, score=0.870 total time=   0.8s
# [CV 6/10] END activation=relu, hidden_layer_sizes=(3, 6), solver=sgd;, score=0.920 total time=   0.9s
# [CV 7/10] END activation=relu, hidden_layer_sizes=(3, 6), solver=sgd;, score=0.940 total time=   0.9s
# [CV 8/10] END activation=relu, hidden_layer_sizes=(3, 6), solver=sgd;, score=0.800 total time=   1.0s
# [CV 9/10] END activation=relu, hidden_layer_sizes=(3, 6), solver=sgd;, score=0.890 total time=   0.6s
# [CV 10/10] END activation=relu, hidden_layer_sizes=(3, 6), solver=sgd;, score=0.870 total time=   0.6s
# [CV 1/10] END activation=relu, hidden_layer_sizes=(3, 6), solver=adam;, score=0.900 total time=   0.5s
# [CV 2/10] END activation=relu, hidden_layer_sizes=(3, 6), solver=adam;, score=0.880 total time=   0.4s
# [CV 3/10] END activation=relu, hidden_layer_sizes=(3, 6), solver=adam;, score=0.870 total time=   0.5s
# [CV 4/10] END activation=relu, hidden_layer_sizes=(3, 6), solver=adam;, score=0.870 total time=   0.5s
# [CV 5/10] END activation=relu, hidden_layer_sizes=(3, 6), solver=adam;, score=0.870 total time=   0.4s
# [CV 6/10] END activation=relu, hidden_layer_sizes=(3, 6), solver=adam;, score=0.920 total time=   0.4s
# [CV 7/10] END activation=relu, hidden_layer_sizes=(3, 6), solver=adam;, score=0.930 total time=   0.4s
# [CV 8/10] END activation=relu, hidden_layer_sizes=(3, 6), solver=adam;, score=0.810 total time=   0.5s
# [CV 9/10] END activation=relu, hidden_layer_sizes=(3, 6), solver=adam;, score=0.880 total time=   0.5s
# [CV 10/10] END activation=relu, hidden_layer_sizes=(3, 6), solver=adam;, score=0.870 total time=   0.4s
# [CV 1/10] END activation=relu, hidden_layer_sizes=(4, 8), solver=lbfgs;, score=1.000 total time=   0.0s
# [CV 2/10] END activation=relu, hidden_layer_sizes=(4, 8), solver=lbfgs;, score=1.000 total time=   0.0s
# [CV 3/10] END activation=relu, hidden_layer_sizes=(4, 8), solver=lbfgs;, score=0.990 total time=   0.0s
# [CV 4/10] END activation=relu, hidden_layer_sizes=(4, 8), solver=lbfgs;, score=1.000 total time=   0.0s
# [CV 5/10] END activation=relu, hidden_layer_sizes=(4, 8), solver=lbfgs;, score=1.000 total time=   0.0s
# [CV 6/10] END activation=relu, hidden_layer_sizes=(4, 8), solver=lbfgs;, score=1.000 total time=   0.0s
# [CV 7/10] END activation=relu, hidden_layer_sizes=(4, 8), solver=lbfgs;, score=1.000 total time=   0.0s
# [CV 8/10] END activation=relu, hidden_layer_sizes=(4, 8), solver=lbfgs;, score=1.000 total time=   0.0s
# [CV 9/10] END activation=relu, hidden_layer_sizes=(4, 8), solver=lbfgs;, score=1.000 total time=   0.0s
# [CV 10/10] END activation=relu, hidden_layer_sizes=(4, 8), solver=lbfgs;, score=1.000 total time=   0.0s
# [CV 1/10] END activation=relu, hidden_layer_sizes=(4, 8), solver=sgd;, score=0.920 total time=   0.6s
# [CV 2/10] END activation=relu, hidden_layer_sizes=(4, 8), solver=sgd;, score=0.890 total time=   0.6s
# [CV 3/10] END activation=relu, hidden_layer_sizes=(4, 8), solver=sgd;, score=0.870 total time=   0.6s
# [CV 4/10] END activation=relu, hidden_layer_sizes=(4, 8), solver=sgd;, score=0.870 total time=   0.6s
# [CV 5/10] END activation=relu, hidden_layer_sizes=(4, 8), solver=sgd;, score=0.870 total time=   0.6s
# [CV 6/10] END activation=relu, hidden_layer_sizes=(4, 8), solver=sgd;, score=0.930 total time=   0.6s
# [CV 7/10] END activation=relu, hidden_layer_sizes=(4, 8), solver=sgd;, score=0.940 total time=   0.9s
# [CV 8/10] END activation=relu, hidden_layer_sizes=(4, 8), solver=sgd;, score=0.810 total time=   1.0s
# [CV 9/10] END activation=relu, hidden_layer_sizes=(4, 8), solver=sgd;, score=0.900 total time=   1.2s
# [CV 10/10] END activation=relu, hidden_layer_sizes=(4, 8), solver=sgd;, score=0.870 total time=   1.0s
# [CV 1/10] END activation=relu, hidden_layer_sizes=(4, 8), solver=adam;, score=0.910 total time=   0.8s
# [CV 2/10] END activation=relu, hidden_layer_sizes=(4, 8), solver=adam;, score=0.890 total time=   0.9s
# [CV 3/10] END activation=relu, hidden_layer_sizes=(4, 8), solver=adam;, score=0.880 total time=   0.9s
# [CV 4/10] END activation=relu, hidden_layer_sizes=(4, 8), solver=adam;, score=0.870 total time=   0.5s
# [CV 5/10] END activation=relu, hidden_layer_sizes=(4, 8), solver=adam;, score=0.910 total time=   0.9s
# [CV 6/10] END activation=relu, hidden_layer_sizes=(4, 8), solver=adam;, score=0.950 total time=   0.8s
# [CV 7/10] END activation=relu, hidden_layer_sizes=(4, 8), solver=adam;, score=0.940 total time=   0.8s
# [CV 8/10] END activation=relu, hidden_layer_sizes=(4, 8), solver=adam;, score=0.810 total time=   0.5s
# [CV 9/10] END activation=relu, hidden_layer_sizes=(4, 8), solver=adam;, score=0.870 total time=   0.9s
# [CV 10/10] END activation=relu, hidden_layer_sizes=(4, 8), solver=adam;, score=0.880 total time=   0.9s
# GridSearchCV(cv=KFold(n_splits=10, random_state=0, shuffle=True),
#              estimator=MLPClassifier(max_iter=5000, random_state=0),
#              param_grid={'activation': ['logistic', 'relu'],
#                          'hidden_layer_sizes': [(4, 2), (3, 4), (3, 6), (4, 8)],
#                          'solver': ['lbfgs', 'sgd', 'adam']},
#              scoring='accuracy', verbose=4)

# %% [markdown]
# ### Melhores hiperparâmetros

# %%
print(gs.best_params_)
# Out:
# {'activation': 'logistic', 'hidden_layer_sizes': (4, 2), 'solver': 'lbfgs'}

# %% [markdown]
# ### Acurácia

# %%
y_pred = gs.predict(X)

acc = accuracy_score(y_pred, y)
print('Accuracy: ', acc)
# Out:
# Accuracy:  1.0

# %% [markdown]
# ### Plotando as regiões de decisão.

# %%
plotDecisionBoundary(gs, X[:,0], X[:,1])
