# %%
# Import all the necessary libraries.
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import PolynomialFeatures
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import Ridge
from sklearn.pipeline import Pipeline
from sklearn.metrics import mean_squared_error
from sklearn.linear_model import LinearRegression
# Out:
# C:\Users\felipe.figueiredo\Anaconda3\lib\site-packages\numpy\_distributor_init.py:32: UserWarning: loaded more than 1 DLL from .libs:
# C:\Users\felipe.figueiredo\Anaconda3\lib\site-packages\numpy\.libs\libopenblas.NOIJJG62EMASZI6NYURL6JBKM4EVBGM7.gfortran-win_amd64.dll
# C:\Users\felipe.figueiredo\Anaconda3\lib\site-packages\numpy\.libs\libopenblas.PYQHXLVVQ7VESDPUVUADXEVJOBGHJPAY.gfortran-win_amd64.dll
#   stacklevel=1)

# %%
# Reset pseudo random number generator so that the results are reproducible.
np.random.seed(42)

# %% [markdown]
# ## Generating the target function and its noisy version.

# %%
# Sets the number of examples.
N = 20

# Create target function and its noisy version.
x = np.sort(3*np.random.rand(N, 1), axis=0)
y = 1 + 0.5*x
y_noisy = y + np.random.randn(N, 1)

# %%
# Plot original data versus noisy version.
plt.plot(x, y, label='Dado original')
plt.plot(x, y_noisy, 'x', label='Dado ruidoso')
#plt.plot(x_test, y_test, 'o', label='Dado teste')
plt.xlabel('$x$', fontsize=14)
plt.ylabel('$y$', fontsize=14)
plt.legend()
plt.grid()
#plt.savefig("target_function.png", dpi=600)
#Show the plot.
plt.show()

# %% [markdown]
# ## polinomial order = 1

# %%
# Polynomial order.
model_order = 1

# %%
# Concatenate both column vectors.
X = np.ones((N,1))
for i in range(1, model_order+1):
    X = np.c_[X, np.power(x, i)]

# Instantiate standard scaler. 
scaler = StandardScaler()

# Train and standardize samples.
X = np.c_[np.ones((N,1)), scaler.fit_transform(X[:,1:])]

reg1 = LinearRegression(fit_intercept=True).fit(X, y_noisy)

ypred = reg1.predict(X)

# Plot original data versus noisy version.
plt.plot(x, y, label='Dado original')
plt.plot(x, y_noisy, 'x', label='Dado ruidoso')
plt.plot(x, ypred, label='Hipótese')
plt.xlabel('$x$', fontsize=14)
plt.ylabel('$y$', fontsize=14)
plt.legend()
plt.grid()
plt.axis([0, 3, 0, 4])
#Show the plot.
plt.show()

# %% [markdown]
# ## polinomial order = 10

# %%
# Polynomial order.
model_order = 10

# %%
# Concatenate both column vectors.
X = np.ones((N,1))
for i in range(1, model_order+1):
    X = np.c_[X, np.power(x, i)]

# Instantiate standard scaler. 
scaler = StandardScaler()

# Train and standardize samples.
X = np.c_[np.ones((N,1)), scaler.fit_transform(X[:,1:])]

reg10 = LinearRegression(fit_intercept=True).fit(X, y_noisy)

ypred = reg10.predict(X)

# Plot original data versus noisy version.
plt.plot(x, y, label='Dado original')
plt.plot(x, y_noisy, 'x', label='Dado ruidoso')
plt.plot(x, ypred, label='Hipótese')
plt.xlabel('$x$', fontsize=14)
plt.ylabel('$y$', fontsize=14)
plt.legend()
plt.grid()
plt.axis([0, 3, 0, 4])
#Show the plot.
plt.show()

# %% [markdown]
# ## polinomial order = 20

# %%
# Polynomial order.
model_order = 20

# %%
# Concatenate both column vectors.
X = np.ones((N,1))
for i in range(1, model_order+1):
    X = np.c_[X, np.power(x, i)]

# Instantiate standard scaler. 
scaler = StandardScaler()

# Train and standardize samples.
X = np.c_[np.ones((N,1)), scaler.fit_transform(X[:,1:])]

reg20 = LinearRegression(fit_intercept=True).fit(X, y_noisy)

ypred = reg20.predict(X)

# Plot original data versus noisy version.
plt.plot(x, y, label='Dado original')
plt.plot(x, y_noisy, 'x', label='Dado ruidoso')
plt.plot(x, ypred, label='Hipótese')
plt.xlabel('$x$', fontsize=14)
plt.ylabel('$y$', fontsize=14)
plt.legend()
plt.grid()
plt.axis([0, 3, 0, 4])
#Show the plot.
plt.show()

# %%
reg1.coef_
# Out:
# array([[0.        , 0.54963632]])

# %%
reg10.coef_
# Out:
# array([[ 0.00000000e+00,  1.80163868e+02, -4.33810514e+03,
#          4.45166386e+04, -2.48521724e+05,  8.32599976e+05,
#         -1.74696276e+06,  2.31229143e+06, -1.87427547e+06,
#          8.49175076e+05, -1.64664226e+05]])

# %%
reg20.coef_
# Out:
# array([[ 8.14816875e+12,  3.58228133e+06, -1.43485397e+08,
#          2.81691737e+09, -3.41720814e+10,  2.81107256e+11,
#         -1.64528788e+12,  7.02858669e+12, -2.21250499e+13,
#          5.09592790e+13, -8.30498668e+13,  8.64909987e+13,
#         -3.50048251e+13, -4.33691991e+13,  7.31793142e+13,
#         -2.04875059e+13, -5.53662285e+13,  7.90569605e+13,
#         -5.01248760e+13,  1.65038082e+13, -2.29572043e+12]])
