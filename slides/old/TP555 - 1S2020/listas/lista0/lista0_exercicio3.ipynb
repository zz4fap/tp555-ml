# %%
import numpy as np
import matplotlib.pyplot as plt

M = 1000

x = np.random.rand(M,1)
w = np.random.randn(M,1)

y = 1.2 + 2.3*x + 10*w

fig = plt.figure()
plt.plot(x, y, '.')
#Show the plot.
plt.show()
